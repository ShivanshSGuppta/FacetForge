# %% [markdown]
# # FacetForge Exploratory Analysis\n\nUse this notebook to inspect processed runs, compare facet score distributions, and prototype calibration analysis against human labels when they are available.
